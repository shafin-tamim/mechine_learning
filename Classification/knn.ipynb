# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv('F:\mechine_learning\Data\Social_Network_Ads.csv')

# %%
df=df[['Age','EstimatedSalary','Purchased']]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x=df.iloc[:, :-1]
y=df['Purchased']

# %%
sns.scatterplot(x='Age',y='EstimatedSalary',hue='Purchased',data=df)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(x)

x= pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=2)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.score(x_test,y_test)
# Out:
# 0.8875

# %%
knn.score(x_train,y_train)
# Out:
# 0.925

# %%
knn.predict([[-1.781797,-1.490046]])
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=knn)
plt.show()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
for i in range(1,30):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    print(f"  {i} Train Score is {knn.score(x_train,y_train)} Test Score is {knn.score(x_test,y_test)}")
# Out:
#   1 Train Score is 0.996875 Test Score is 0.8875
#   2 Train Score is 0.925 Test Score is 0.8875
#   3 Train Score is 0.915625 Test Score is 0.95
#   4 Train Score is 0.90625 Test Score is 0.95
#   5 Train Score is 0.91875 Test Score is 0.95
#   6 Train Score is 0.9125 Test Score is 0.95
#   7 Train Score is 0.909375 Test Score is 0.95
#   8 Train Score is 0.909375 Test Score is 0.95
#   9 Train Score is 0.9125 Test Score is 0.95
#   10 Train Score is 0.909375 Test Score is 0.95
#   11 Train Score is 0.915625 Test Score is 0.95
#   12 Train Score is 0.90625 Test Score is 0.95
#   13 Train Score is 0.909375 Test Score is 0.95
#   14 Train Score is 0.90625 Test Score is 0.95
#   15 Train Score is 0.909375 Test Score is 0.95
#   16 Train Score is 0.90625 Test Score is 0.95
#   17 Train Score is 0.9125 Test Score is 0.95
#   18 Train Score is 0.90625 Test Score is 0.95
#   19 Train Score is 0.909375 Test Score is 0.95
#   20 Train Score is 0.903125 Test Score is 0.95
# ...
