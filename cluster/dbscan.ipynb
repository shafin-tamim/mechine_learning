# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=250, noise=0.05)

# %%
df= {"data1": x[:,0], "data2": x[:,1],}

# %%
data= pd.DataFrame(df)

# %%
data.head(2)
# Out:
#       data1     data2
# 0 -0.087186  0.398847
# 1  1.929678  0.396657

# %%
sns.scatterplot(data=data, x="data1", y="data2")
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.2, min_samples=5)
data['predict']=db.fit_predict(data)

# %%
data.head(5)
# Out:
#       data1     data2  predict
# 0 -0.087186  0.398847        0
# 1  1.929678  0.396657        0
# 2  0.915150  0.361200        0
# 3  0.980623  0.316041        0
# 4  1.676142 -0.303517        0

# %%
sns.scatterplot(data=data, x="data1", y="data2",hue="predict")
plt.show()
